# %%
import pandas as pd
df = pd.read_csv('citrus.csv')

# %%
df.info()

# %%
df.head(10000)
# Out:
#      name  diameter  weight  red  green  blue
# 0       0      2.96   86.76  172     85     2
# 1       0      3.91   88.05  166     78     3
# 2       0      4.42   95.17  156     81     2
# 3       0      4.47   95.60  163     81     4
# 4       0      4.48   95.76  161     72     9
# ...   ...       ...     ...  ...    ...   ...
# 9995    1     15.35  253.89  149     77    20
# 9996    1     15.41  254.67  148     68     7
# 9997    1     15.59  256.50  168     82    20
# 9998    1     15.92  260.14  142     72    11
# 9999    1     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %%
df.name[df.name == 'orange'] = 0
df.name[df.name == 'grapefruit'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[0, 2.96, 86.76, 172, 85, 2],
#        [0, 3.91, 88.05, 166, 78, 3],
#        [0, 4.42, 95.17, 156, 81, 2],
#        ...,
#        [1, 15.59, 256.5, 168, 82, 20],
#        [1, 15.92, 260.14, 142, 72, 11],
#        [1, 16.45, 261.51, 152, 74, 2]], dtype=object)

# %%
# pilih 5 kolom terakhir sebagai atribut
X = dataset[:,1:6]
# bilangan sebelum koma untuk memilih baris pada dataframe
# bilangan setelah koma untuk memilih kolom pada dataframe

# %%
y = dataset[:,0]

# %%
# Normalization
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.        , 0.        , 0.74025974, 0.63529412, 0.        ],
#        [0.07042254, 0.00738197, 0.66233766, 0.55294118, 0.01851852],
#        [0.10822832, 0.04812589, 0.53246753, 0.58823529, 0.        ],
#        ...,
#        [0.93624907, 0.97133047, 0.68831169, 0.6       , 0.33333333],
#        [0.96071164, 0.99216023, 0.35064935, 0.48235294, 0.16666667],
#        [1.        , 1.        , 0.48051948, 0.50588235, 0.        ]])

# %%
# pisahkan data training dan testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
import numpy as np
 
Y_train = Y_train.astype(np.float32)
Y_test = Y_test.astype(np.float32)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([    
                    Dense(32, activation='relu', input_shape=(5,)),    
                    Dense(32, activation='relu'),    
                    Dense(1, activation='sigmoid'),])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.6672 - accuracy: 0.5567
# Epoch 2/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.6291 - accuracy: 0.7961
# Epoch 3/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5812 - accuracy: 0.8763
# Epoch 4/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.9014
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.9169
# Epoch 6/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.9243
# Epoch 7/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.9266
# Epoch 8/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.9271
# Epoch 9/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9267
# Epoch 10/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9280
# Epoch 11/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1992 - accuracy: 0.9291
# Epoch 12/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9284
# Epoch 13/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.9287
# Epoch 14/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9287
# Epoch 15/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1814 - accuracy: 0.9277
# Epoch 16/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9287
# Epoch 17/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1784 - accuracy: 0.9271
# Epoch 18/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1780 - accuracy: 0.9281
# Epoch 19/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1771 - accuracy: 0.9297
# Epoch 20/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1770 - accuracy: 0.9281
# Epoch 21/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.9279
# Epoch 22/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9286
# Epoch 23/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1761 - accuracy: 0.9299
# Epoch 24/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9289
# Epoch 25/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9286
# Epoch 26/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9280
# Epoch 27/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9304
# Epoch 28/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9287
# Epoch 29/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.9291
# Epoch 30/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9286
# Epoch 31/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.9290
# Epoch 32/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.9286
# Epoch 33/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9284
# Epoch 34/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9283
# Epoch 35/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9286
# Epoch 36/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1750 - accuracy: 0.9287
# Epoch 37/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9271
# Epoch 38/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9281
# Epoch 39/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1750 - accuracy: 0.9289
# Epoch 40/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9283
# Epoch 41/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9279
# Epoch 42/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9287
# Epoch 43/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9283
# Epoch 44/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9283
# Epoch 45/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9279
# Epoch 46/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9281
# Epoch 47/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9299
# Epoch 48/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9289
# Epoch 49/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9283
# Epoch 50/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9284
# Epoch 51/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9283
# Epoch 52/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9281
# Epoch 53/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9287
# Epoch 54/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9280
# Epoch 55/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9287
# Epoch 56/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9284
# Epoch 57/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9286
# Epoch 58/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9270
# Epoch 59/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9304
# Epoch 60/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9286
# Epoch 61/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9290
# Epoch 62/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9277
# Epoch 63/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9281
# Epoch 64/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9269
# Epoch 65/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.1745 - accuracy: 0.9286
# Epoch 66/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9283
# Epoch 67/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9284
# Epoch 68/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9287
# Epoch 69/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1743 - accuracy: 0.9287
# Epoch 70/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9283
# Epoch 71/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9297
# Epoch 72/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1743 - accuracy: 0.9289
# Epoch 73/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9291
# Epoch 74/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9281
# Epoch 75/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9301
# Epoch 76/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9279
# Epoch 77/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9264
# Epoch 78/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9287
# Epoch 79/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1739 - accuracy: 0.9283
# Epoch 80/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9293
# Epoch 81/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 0.9290
# Epoch 82/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9294
# Epoch 83/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9299
# Epoch 84/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9283
# Epoch 85/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9300
# Epoch 86/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1739 - accuracy: 0.9283
# Epoch 87/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9283
# Epoch 88/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1735 - accuracy: 0.9296
# Epoch 89/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9284
# Epoch 90/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9281
# Epoch 91/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9281
# Epoch 92/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1735 - accuracy: 0.9300
# Epoch 93/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9287
# Epoch 94/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9291
# Epoch 95/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1729 - accuracy: 0.9279
# Epoch 96/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9283
# Epoch 97/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9287
# Epoch 98/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9280
# Epoch 99/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9284
# Epoch 100/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9290

# %%
model.evaluate(X_test, Y_test)
# elemen pertama adalah loss dan elemen kedua adalah akurasi
# Out:
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.9260
# [0.18826165795326233, 0.9259999990463257]

# %%
import tensorflow as tf
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
df = pd.read_csv('Iris.csv')
df = df.drop(columns='Id')
category = pd.get_dummies(df.Species)
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
dataset = new_df.values
X = dataset[:,0:4]
y = dataset[:,4:7]
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)
model = Sequential([    
                    Dense(64, activation='relu', input_shape=(4,)),    
                    Dense(64, activation='relu'),    
                    Dense(3, activation='sigmoid'),])
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      print("\nAkurasi telah mencapai >90%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
model.fit(X_train, Y_train, epochs=50, callbacks=[callbacks])
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 5ms/step - loss: 1.1812 - accuracy: 0.3524
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1205 - accuracy: 0.4000
# Epoch 3/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0687 - accuracy: 0.6762
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0269 - accuracy: 0.6762
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9874 - accuracy: 0.6667
# Epoch 6/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9512 - accuracy: 0.6667
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9151 - accuracy: 0.6667
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8803 - accuracy: 0.6667
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8454 - accuracy: 0.6667
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8115 - accuracy: 0.6667
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7774 - accuracy: 0.6667
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.6667
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7101 - accuracy: 0.6952
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.7333
# Epoch 15/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6458 - accuracy: 0.7524
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6154 - accuracy: 0.7143
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.6762
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5607 - accuracy: 0.6762
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5364 - accuracy: 0.7048
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5159 - accuracy: 0.7048
# Epoch 21/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4976 - accuracy: 0.7143
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4800 - accuracy: 0.7333
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.7619
# Epoch 24/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4516 - accuracy: 0.8571
# Epoch 25/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4765 - accuracy: 0.8438
# Akurasi telah mencapai >90%!
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4412 - accuracy: 0.9143
